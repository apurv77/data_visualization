# %%
import matplotlib.pyplot as plt
# %matplotlib inline
#show plots
import numpy as np
import pandas as pd

# %reload_ext autoreload
# %autoreload 2
#reload page

#chart 1

x_mb_s3 = ([0.1, 1, 2, 4, 6, 8, 10])
y_time_s3 = ([1.35, 2.23, 1.95, 2.24, 2.46, 3.26, 3.75])

#x_mb_el = ([10, 50, 100])
#y_time_el = ([7, 14, 21])

x_mb_k8s = ([0.1, 1, 2, 4, 6, 8, 10])
y_time_k8s = ([0.45, 0.5, 0.53, 0.76, 0.95, 1.13, 2.6])

# %%
size_vs_extime = plt.figure(figsize=(7,6), dpi=100)
sz_ex_axes = size_vs_extime.add_axes([0.1, 0.1, 0.9, 0.9])
sz_ex_axes.set_xlabel('Size(mb)', fontsize=15)
sz_ex_axes.set_ylabel('Execution Time(s)', fontsize=15)
sz_ex_axes.set_title('Size vs Execution Time', fontsize=17)
sz_ex_axes.plot(x_mb_s3, y_time_s3, label='Lambda S3', color='red', alpha=.75, lw=2, ls='-.',
           marker='s', markersize=7, markerfacecolor='black',
           markeredgecolor='black', markeredgewidth=2)
#sz_ex_axes.plot(x_mb_el, y_time_el, label='Lambda ElastiCache', color='orange', alpha=.75, lw=2, ls='-.',
#           marker='s', markersize=7, markerfacecolor='black',
#           markeredgecolor='black', markeredgewidth=2)
sz_ex_axes.plot(x_mb_k8s, y_time_k8s, label='k8s', color='blue', alpha=.75, lw=2, ls='-.',
           marker='s', markersize=7, markerfacecolor='black',
           markeredgecolor='black', markeredgewidth=2)
sz_ex_axes.legend(loc=0)
size_vs_extime.savefig('SzVsEx.png')

# %%
#chart 2 (size vs memory usage)
x_mb_s3_2 = ([0.1, 1, 2, 4, 6, 8, 10])
y_time_s3_2 = ([18, 22, 24, 32, 40, 47, 54])

x_mb_k8s_2 = ([0.1, 1, 2, 4, 6, 8, 10])
y_time_k8s_2 = ([47, 48, 47, 49, 51, 56, 80])

# %%
size_vs_mu = plt.figure(figsize=(7,6), dpi=100)
sz_mu_axes = size_vs_mu.add_axes([0.1, 0.1, 0.9, 0.9])
sz_mu_axes.set_xlabel('Size(mb)', fontsize=15)
sz_mu_axes.set_ylabel('Memory Usage(mb)', fontsize=15)
sz_mu_axes.set_title('Size vs Memory Usage', fontsize=17)
sz_mu_axes.plot(x_mb_s3_2, y_time_s3_2, label='Lambda S3', color='red', alpha=.75, lw=2, ls='-.',
           marker='s', markersize=7, markerfacecolor='black',
           markeredgecolor='black', markeredgewidth=2)
#sz_ex_axes.plot(x_mb_el, y_time_el, label='Lambda ElastiCache', color='orange', alpha=.75, lw=2, ls='-.',
#           marker='s', markersize=7, markerfacecolor='black',
#           markeredgecolor='black', markeredgewidth=2)
sz_mu_axes.plot(x_mb_k8s_2, y_time_k8s_2, label='k8s', color='blue', alpha=.75, lw=2, ls='-.',
           marker='s', markersize=7, markerfacecolor='black',
           markeredgecolor='black', markeredgewidth=2)
sz_mu_axes.legend(loc=0)
size_vs_mu.savefig('SzVsMem.png')
